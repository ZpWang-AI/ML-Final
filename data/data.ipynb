# %%
import pandas as pd

data_filepath = './raw_data/ETTh1.csv'
# data_filepath = './raw_data/ETTh2.csv'

df = pd.read_csv(data_filepath)
df
# df.columns
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...

# %%
processed_data_filepath = './train_data/EETh1_96_96.csv'

df = pd.read_csv(processed_data_filepath)
df
# Out:
#        Unnamed: 0  var1(t-96)  var2(t-96)  var3(t-96)  var4(t-96)  var5(t-96)  \
# 0              96       5.827       2.009       1.599       0.462       4.203
# 1              97       5.693       2.076       1.492       0.426       4.142
# 2              98       5.157       1.741       1.279       0.355       3.777
# 3              99       5.090       1.942       1.279       0.391       3.807
# 4             100       5.358       1.942       1.492       0.462       3.868
# ...           ...         ...         ...         ...         ...         ...
# 17224       17320       0.469       2.210      -2.416       0.640       3.290
# 17225       17321       2.880       1.942      -0.640       0.391       3.503
# 17226       17322       6.966       2.210       3.589       0.533       3.381
# 17227       17323       8.640       1.942       5.543       0.533       3.107
# 17228       17324      11.454       2.411       7.320       0.675       4.112
#
# ...
